# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Desktop/desvios.txt")
df
# Out:
#       null   SDHori  SDHeig  Q
# 0      NaN    1.052   1.859  6
# 1      NaN    1.031   1.878  6
# 2      NaN    1.035   1.927  6
# 3      NaN    1.039   1.975  6
# 4      NaN    1.042   2.020  6
# ...    ...      ...     ... ..
# 9074   NaN    0.018   0.027  1
# 9075   NaN    0.018   0.027  1
# 9076   NaN    0.018   0.027  2
# 9077   NaN    0.109   0.209  2
# 9078   NaN   21.562  16.723  6
#
# [9079 rows x 4 columns]

# %%
#desvio padrao e Quality maximo

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.bar(df.index,df["Q"],color=(0.1, 0.1, 0.1,0.1),label="Quality",edgecolor="b")
ax.legend(loc='upper center')
ax.plot(10)

ax2 = ax.twinx()

ax2.plot(df.index,df["SDHeig"],label="Desvio Padrão Horizontal",linestyle='dashed',color="y")
ax2.plot(df.index,df[" SDHori"],label="Desvio Padrão Vertical",linestyle='dashed', color="r")
ax2.plot(20)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.bar(df["Q"],df["SDHeig"],label="Quality x SD Vertical",edgecolor="b")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.bar(df["Q"],df[" SDHori"],label="Quality x SD Horizontal",edgecolor="r")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.plot(df.index,df[" SDHori"],linestyle='dashed', color="r")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.plot(df.index,df["SDHeig"],linestyle='dashed', color="g")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.plot(df["Q"],df["SDHeig"],linestyle='dashed', color="g")
plt.show()

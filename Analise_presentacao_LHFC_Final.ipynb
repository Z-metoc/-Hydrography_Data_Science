# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Desktop/desvio_final")
df
# Out:
#       null  SDHori  SDHeig  Q
# 0            1.052   1.859  6
# 1            1.031   1.878  6
# 2            1.035   1.928  6
# 3            1.039   1.975  6
# 4            1.042   2.021  6
# ...    ...     ...     ... ..
# 9074         0.018   0.027  1
# 9075         0.018   0.027  1
# 9076         0.018   0.027  2
# 9077         0.109   0.209  2
# 9078   NaN  21.563  16.723  6
#
# [9079 rows x 4 columns]

# %%
#desvio padrao e Quality maximo

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.plot(df.index,df["Q"],label="QUALIDADE",linestyle="dashed",color= "g")
ax.legend(loc="upper center")
ax.set_ylabel
ax2 = ax.twinx()

ax2.plot(df.index,df["SDHeig"],label="Desvio Padrão Horizontal",color="y")
ax2.plot(df.index,df["SDHori"],label="Desvio Padrão Vertical",color="r")
ax2.plot(30)

ax.set_ylabel("QUALIDADE")
ax2.set_ylabel("DESVIO PADRÃO")
ax.set_xlabel("TEMPO(Segundos)")

plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.plot(df.index,df["SDHori"],linestyle='dashed',label="Desvio Padrão Horizontal (MIN,MAX,MÉDIO) = (0.01, 21.56, 0.026) ", color="r")
ax.legend(loc='upper center')
ax.set_xlabel("TEMPO (Segundos) = 2h e 30 min")
ax.set_ylabel("DESVIO PADRÃO HORIZONTAL (m)")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,9))
ax.plot(df.index,df["SDHeig"],label="Desvio Padrão Vertical (MIN,MAX,MÉDIO) = (0.016, 16.723, 0.049) ",linestyle='dashed', color="y")
ax.legend(loc='upper center')
ax.set_xlabel("TEMPO (Segundos) = 2h e 30 min")
ax.set_ylabel("DESVIO PADRÃO VERTICAL (m)")
plt.show()

# %%
devhei_min=df["SDHeig"].min()
devhei_min
# Out:
# 0.016

# %%
devhei_max=df["SDHeig"].max()
devhei_max
# Out:
# 16.723

# %%
devho_min=df["SDHori"].min()
devho_min
# Out:
# 0.01

# %%
devho_max=df["SDHori"].max()
devho_max
# Out:
# 21.563000000000002

# %%
devhomean=df["SDHori"].mean()
devhomean
# Out:
# 0.02696222050886881

# %%
devheimean=df["SDHeig"].mean()
devheimean
# Out:
# 0.04916389470205874

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     a MATLAB-like way of plotting.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The object-oriented API is recommended for more complex plots.
#
# FUNCTIONS
#     acorr(x, *, data=None, **kwargs)
#         Plot the autocorrelation of *x*.
#
#         Parameters
#         ----------
#         x : array-like
#
#         detrend : callable, optional, default: `mlab.detrend_none`
#             *x* is detrended by the *detrend* callable. This must be a
#             function ``x = detrend(x)`` accepting and returning an
#             `numpy.array`. Default is no normalization.
#
# ...
